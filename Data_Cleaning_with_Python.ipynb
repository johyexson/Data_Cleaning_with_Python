# %%
# importing package for data cleaning
import pandas as pd
data= pd.read_csv(r'telecom_customer_churn.csv')
data.head()
# Out:
#   Customer_ID  Gender   Age Married   Dependents          City  Zip_Code  \
# 0  0002-ORFBO  Female  37.0     Yes          0.0  Frazier Park   93225.0
# 1  0003-MKNFE    Male  46.0      No          0.0      Glendale   91206.0
# 2  0004-TLHLJ    Male  50.0      No          0.0    Costa Mesa   92627.0
# 3  0011-IGKFF    Male  78.0     Yes          0.0      Martinez   94553.0
# 4  0013-EXCHZ  Female  75.0     Yes          0.0     Camarillo   93010.0
#
#     Latitude   Longitude  Referrals  ...   Payment_Method Monthly_Charge  \
# 0  34.827662 -118.999073        2.0  ...      Credit Card           65.6
# 1  34.162515 -118.203869        0.0  ...      Credit Card           -4.0
# 2  33.645672 -117.922613        0.0  ...  Bank Withdrawal           73.9
# 3  38.014457 -122.115432        1.0  ...  Bank Withdrawal           98.0
# 4  34.227846 -119.079903        3.0  ...      Credit Card           83.9
#
#   Total_Charges  Total_Refunds Total_Extra_Data_Charges  \
# ...

# %%
# viewing information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7046 entries, 0 to 7045
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer_ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   float64
#  3   Married                            7043 non-null   object
#  4    Dependents                        7043 non-null   float64
#  5   City                               7043 non-null   object
#  6   Zip_Code                           7043 non-null   float64
#  7   Latitude                           7043 non-null   float64
#  8   Longitude                          7043 non-null   float64
#  9   Referrals                          7043 non-null   float64
#  10  Tenure                             7043 non-null   float64
# ...

# %%
data.describe()
# Out:
#                Age   Dependents      Zip_Code     Latitude    Longitude  \
# count  7043.000000  7043.000000   7043.000000  7043.000000  7043.000000
# mean     46.509726     0.468692  93486.070567    36.197455  -119.756684
# std      16.750352     0.962802   1856.767505     2.468929     2.154425
# min      19.000000     0.000000  90001.000000    32.555828  -124.301372
# 25%      32.000000     0.000000  92101.000000    33.990646  -121.788090
# 50%      46.000000     0.000000  93518.000000    36.205465  -119.595293
# 75%      60.000000     0.000000  95329.000000    38.161321  -117.969795
# max      80.000000     9.000000  96150.000000    41.962127  -114.192901
#
#          Referrals       Tenure  Avg_Monthly_Long_Distance_Charges  \
# count  7043.000000  7043.000000                        7043.000000
# mean      1.951867    32.386767                          22.958954
# std       3.001199    24.542061                          15.448113
# ...

# %%
# checking for duplicates
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7041    False
# 7042    False
# 7043    False
# 7044     True
# 7045     True
# Length: 7046, dtype: bool

# %%
data.count()
# Out:
# Customer_ID                          7043
# Gender                               7043
# Age                                  7043
# Married                              7043
#  Dependents                          7043
# City                                 7043
# Zip_Code                             7043
# Latitude                             7043
# Longitude                            7043
# Referrals                            7043
# Tenure                               7043
# Offer                                7043
# Phone_Service                        7043
# Avg_Monthly_Long_Distance_Charges    7043
# Multiple_Lines                       7043
# Internet_Service                     7043
# Internet_Type                        7043
# Avg_Monthly_GB Download              7043
# Online_Security                      7043
# Online_Backup                        7043
# Device_Protection_Plan               7043
# Premium Tech Support                 7043
# ...

# %%
data.duplicated().sum()
# Out:
# 2

# %%
# removing duplicates from the data
data.drop_duplicates(inplace= True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.head()
# Out:
#   Customer_ID  Gender   Age Married   Dependents          City  Zip_Code  \
# 0  0002-ORFBO  Female  37.0     Yes          0.0  Frazier Park   93225.0
# 1  0003-MKNFE    Male  46.0      No          0.0      Glendale   91206.0
# 2  0004-TLHLJ    Male  50.0      No          0.0    Costa Mesa   92627.0
# 3  0011-IGKFF    Male  78.0     Yes          0.0      Martinez   94553.0
# 4  0013-EXCHZ  Female  75.0     Yes          0.0     Camarillo   93010.0
#
#     Latitude   Longitude  Referrals  ...   Payment_Method Monthly_Charge  \
# 0  34.827662 -118.999073        2.0  ...      Credit Card           65.6
# 1  34.162515 -118.203869        0.0  ...      Credit Card           -4.0
# 2  33.645672 -117.922613        0.0  ...  Bank Withdrawal           73.9
# 3  38.014457 -122.115432        1.0  ...  Bank Withdrawal           98.0
# 4  34.227846 -119.079903        3.0  ...      Credit Card           83.9
#
#   Total_Charges  Total_Refunds Total_Extra_Data_Charges  \
# ...

# %%
# removing irrelevant columns
data.drop(columns= ["Latitude", "Longitude"], inplace = True)

# %%
data.columns
# Out:
# Index(['Customer_ID', 'Gender', 'Age', 'Married', ' Dependents', 'City',
#        'Zip_Code', 'Referrals', 'Tenure', 'Offer', 'Phone_Service',
#        'Avg_Monthly_Long_Distance_Charges', 'Multiple_Lines',
#        'Internet_Service', 'Internet_Type', 'Avg_Monthly_GB Download',
#        'Online_Security', 'Online_Backup', 'Device_Protection_Plan',
#        'Premium Tech Support', 'Streaming_TV', 'Streaming_Movies',
#        'Streaming_Music', 'Unlimited_Data', 'Contract', 'Paperless_Billing',
#        'Payment_Method', 'Monthly_Charge', 'Total_Charges', 'Total_Refunds',
#        'Total_Extra_Data_Charges', 'Total_Long_Distance_Charges',
#        'Total_Revenue', 'Customer_Status', 'Churn_Category', 'Churn_Reason'],
#       dtype='object')

# %%
# checking to see if the changes have been effected in the data
data.head()
# Out:
#   Customer_ID  Gender   Age Married   Dependents          City  Zip_Code  \
# 0  0002-ORFBO  Female  37.0     Yes          0.0  Frazier Park   93225.0
# 1  0003-MKNFE    Male  46.0      No          0.0      Glendale   91206.0
# 2  0004-TLHLJ    Male  50.0      No          0.0    Costa Mesa   92627.0
# 3  0011-IGKFF    Male  78.0     Yes          0.0      Martinez   94553.0
# 4  0013-EXCHZ  Female  75.0     Yes          0.0     Camarillo   93010.0
#
#    Referrals  Tenure    Offer  ...   Payment_Method  Monthly_Charge  \
# 0        2.0     9.0     None  ...      Credit Card            65.6
# 1        0.0     9.0     None  ...      Credit Card            -4.0
# 2        0.0     4.0  Offer E  ...  Bank Withdrawal            73.9
# 3        1.0    13.0  Offer D  ...  Bank Withdrawal            98.0
# 4        3.0     3.0     None  ...      Credit Card            83.9
#
#   Total_Charges Total_Refunds Total_Extra_Data_Charges  \
# 0        593.30          0.00                      0.0
# ...

# %%
# filling columns that has null values
data.fillna('Not Applicable')
# Out:
#          Customer_ID          Gender             Age         Married  \
# 0         0002-ORFBO          Female            37.0             Yes
# 1         0003-MKNFE            Male            46.0              No
# 2         0004-TLHLJ            Male            50.0              No
# 3         0011-IGKFF            Male            78.0             Yes
# 4         0013-EXCHZ          Female            75.0             Yes
# ...              ...             ...             ...             ...
# 7039      9992-RRAMN            Male            40.0             Yes
# 7040      9992-UJOEL            Male            22.0              No
# 7041      9993-LHIEB            Male            21.0             Yes
# 7042      9995-HOTOH            Male            36.0             Yes
# 7043  Not Applicable  Not Applicable  Not Applicable  Not Applicable
#
#           Dependents            City        Zip_Code       Referrals  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7044 entries, 0 to 7043
# Data columns (total 36 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer_ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   float64
#  3   Married                            7043 non-null   object
#  4    Dependents                        7043 non-null   float64
#  5   City                               7043 non-null   object
#  6   Zip_Code                           7043 non-null   float64
#  7   Referrals                          7043 non-null   float64
#  8   Tenure                             7043 non-null   float64
#  9   Offer                              7043 non-null   object
#  10  Phone_Service                      7043 non-null   object
# ...

# %%
data.head()
# Out:
#   Customer_ID  Gender   Age Married   Dependents          City  Zip_Code  \
# 0  0002-ORFBO  Female  37.0     Yes          0.0  Frazier Park   93225.0
# 1  0003-MKNFE    Male  46.0      No          0.0      Glendale   91206.0
# 2  0004-TLHLJ    Male  50.0      No          0.0    Costa Mesa   92627.0
# 3  0011-IGKFF    Male  78.0     Yes          0.0      Martinez   94553.0
# 4  0013-EXCHZ  Female  75.0     Yes          0.0     Camarillo   93010.0
#
#    Referrals  Tenure    Offer  ...   Payment_Method  Monthly_Charge  \
# 0        2.0     9.0     None  ...      Credit Card            65.6
# 1        0.0     9.0     None  ...      Credit Card            -4.0
# 2        0.0     4.0  Offer E  ...  Bank Withdrawal            73.9
# 3        1.0    13.0  Offer D  ...  Bank Withdrawal            98.0
# 4        3.0     3.0     None  ...      Credit Card            83.9
#
#   Total_Charges Total_Refunds Total_Extra_Data_Charges  \
# 0        593.30          0.00                      0.0
# ...

# %%
data.isnull()
# Out:
#       Customer_ID  Gender    Age  Married   Dependents   City  Zip_Code  \
# 0           False   False  False    False        False  False     False
# 1           False   False  False    False        False  False     False
# 2           False   False  False    False        False  False     False
# 3           False   False  False    False        False  False     False
# 4           False   False  False    False        False  False     False
# ...           ...     ...    ...      ...          ...    ...       ...
# 7039        False   False  False    False        False  False     False
# 7040        False   False  False    False        False  False     False
# 7041        False   False  False    False        False  False     False
# 7042        False   False  False    False        False  False     False
# 7043         True    True   True     True         True   True      True
#
#       Referrals  Tenure  Offer  ...  Payment_Method  Monthly_Charge  \
# ...

# %%
data.isnull().sum()
# Out:
# Customer_ID                             1
# Gender                                  1
# Age                                     1
# Married                                 1
#  Dependents                             1
# City                                    1
# Zip_Code                                1
# Referrals                               1
# Tenure                                  1
# Offer                                   1
# Phone_Service                           1
# Avg_Monthly_Long_Distance_Charges       1
# Multiple_Lines                          1
# Internet_Service                        1
# Internet_Type                           1
# Avg_Monthly_GB Download                 1
# Online_Security                         1
# Online_Backup                           1
# Device_Protection_Plan                  1
# Premium Tech Support                    1
# Streaming_TV                            1
# Streaming_Movies                        1
# ...

# %%
# removing an empty row
data.drop(index=7043, inplace= True)

# %%
data.isnull().sum()
# Out:
# Customer_ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
#  Dependents                             0
# City                                    0
# Zip_Code                                0
# Referrals                               0
# Tenure                                  0
# Offer                                   0
# Phone_Service                           0
# Avg_Monthly_Long_Distance_Charges       0
# Multiple_Lines                          0
# Internet_Service                        0
# Internet_Type                           0
# Avg_Monthly_GB Download                 0
# Online_Security                         0
# Online_Backup                           0
# Device_Protection_Plan                  0
# Premium Tech Support                    0
# Streaming_TV                            0
# Streaming_Movies                        0
# ...

# %%
# filling columns that have null values
data.fillna('Not Applicable', inplace= True)

# %%
data.head()
# Out:
#   Customer_ID  Gender   Age Married   Dependents          City  Zip_Code  \
# 0  0002-ORFBO  Female  37.0     Yes          0.0  Frazier Park   93225.0
# 1  0003-MKNFE    Male  46.0      No          0.0      Glendale   91206.0
# 2  0004-TLHLJ    Male  50.0      No          0.0    Costa Mesa   92627.0
# 3  0011-IGKFF    Male  78.0     Yes          0.0      Martinez   94553.0
# 4  0013-EXCHZ  Female  75.0     Yes          0.0     Camarillo   93010.0
#
#    Referrals  Tenure    Offer  ...   Payment_Method  Monthly_Charge  \
# 0        2.0     9.0     None  ...      Credit Card            65.6
# 1        0.0     9.0     None  ...      Credit Card            -4.0
# 2        0.0     4.0  Offer E  ...  Bank Withdrawal            73.9
# 3        1.0    13.0  Offer D  ...  Bank Withdrawal            98.0
# 4        3.0     3.0     None  ...      Credit Card            83.9
#
#   Total_Charges Total_Refunds Total_Extra_Data_Charges  \
# 0        593.30          0.00                      0.0
# ...

# %%
# checking to see if the changes have been effected in the data
data.isnull().sum()
# Out:
# Customer_ID                          0
# Gender                               0
# Age                                  0
# Married                              0
#  Dependents                          0
# City                                 0
# Zip_Code                             0
# Referrals                            0
# Tenure                               0
# Offer                                0
# Phone_Service                        0
# Avg_Monthly_Long_Distance_Charges    0
# Multiple_Lines                       0
# Internet_Service                     0
# Internet_Type                        0
# Avg_Monthly_GB Download              0
# Online_Security                      0
# Online_Backup                        0
# Device_Protection_Plan               0
# Premium Tech Support                 0
# Streaming_TV                         0
# Streaming_Movies                     0
# Streaming_Music                      0
# Unlimited_Data                       0
# ...

# %%
data.columns
# Out:
# Index(['Customer_ID', 'Gender', 'Age', 'Married', ' Dependents', 'City',
#        'Zip_Code', 'Referrals', 'Tenure', 'Offer', 'Phone_Service',
#        'Avg_Monthly_Long_Distance_Charges', 'Multiple_Lines',
#        'Internet_Service', 'Internet_Type', 'Avg_Monthly_GB Download',
#        'Online_Security', 'Online_Backup', 'Device_Protection_Plan',
#        'Premium Tech Support', 'Streaming_TV', 'Streaming_Movies',
#        'Streaming_Music', 'Unlimited_Data', 'Contract', 'Paperless_Billing',
#        'Payment_Method', 'Monthly_Charge', 'Total_Charges', 'Total_Refunds',
#        'Total_Extra_Data_Charges', 'Total_Long_Distance_Charges',
#        'Total_Revenue', 'Customer_Status', 'Churn_Category', 'Churn_Reason'],
#       dtype='object')

# %%
# changing data type for the age column
data['Age']= data['Age'].astype(int)

# %%
data.head()
# Out:
#   Customer_ID  Gender  Age Married   Dependents          City  Zip_Code  \
# 0  0002-ORFBO  Female   37     Yes          0.0  Frazier Park   93225.0
# 1  0003-MKNFE    Male   46      No          0.0      Glendale   91206.0
# 2  0004-TLHLJ    Male   50      No          0.0    Costa Mesa   92627.0
# 3  0011-IGKFF    Male   78     Yes          0.0      Martinez   94553.0
# 4  0013-EXCHZ  Female   75     Yes          0.0     Camarillo   93010.0
#
#    Referrals  Tenure    Offer  ...   Payment_Method  Monthly_Charge  \
# 0        2.0     9.0     None  ...      Credit Card            65.6
# 1        0.0     9.0     None  ...      Credit Card            -4.0
# 2        0.0     4.0  Offer E  ...  Bank Withdrawal            73.9
# 3        1.0    13.0  Offer D  ...  Bank Withdrawal            98.0
# 4        3.0     3.0     None  ...      Credit Card            83.9
#
#   Total_Charges Total_Refunds Total_Extra_Data_Charges  \
# 0        593.30          0.00                      0.0
# ...

# %%
data.dtypes
# Out:
# Customer_ID                           object
# Gender                                object
# Age                                    int32
# Married                               object
#  Dependents                          float64
# City                                  object
# Zip_Code                             float64
# Referrals                            float64
# Tenure                               float64
# Offer                                 object
# Phone_Service                         object
# Avg_Monthly_Long_Distance_Charges    float64
# Multiple_Lines                        object
# Internet_Service                      object
# Internet_Type                         object
# Avg_Monthly_GB Download              float64
# Online_Security                       object
# Online_Backup                         object
# Device_Protection_Plan                object
# Premium Tech Support                  object
# Streaming_TV                          object
# ...

# %%
# changing the data type for multiple columns in the data
data= data.astype({' Dependents': 'int','Zip_Code': 'int','Referrals': 'int','Tenure': 'int','Avg_Monthly_Long_Distance_Charges': 'int','Avg_Monthly_GB Download': 'int','Monthly_Charge': 'int','Total_Charges': 'int','Total_Refunds': 'int','Total_Extra_Data_Charges': 'int','Total_Long_Distance_Charges': 'int','Total_Revenue': 'int'})

# %%
data.head()
# Out:
#   Customer_ID  Gender  Age Married   Dependents          City  Zip_Code  \
# 0  0002-ORFBO  Female   37     Yes            0  Frazier Park     93225
# 1  0003-MKNFE    Male   46      No            0      Glendale     91206
# 2  0004-TLHLJ    Male   50      No            0    Costa Mesa     92627
# 3  0011-IGKFF    Male   78     Yes            0      Martinez     94553
# 4  0013-EXCHZ  Female   75     Yes            0     Camarillo     93010
#
#    Referrals  Tenure    Offer  ...   Payment_Method  Monthly_Charge  \
# 0          2       9     None  ...      Credit Card              65
# 1          0       9     None  ...      Credit Card              -4
# 2          0       4  Offer E  ...  Bank Withdrawal              73
# 3          1      13  Offer D  ...  Bank Withdrawal              98
# 4          3       3     None  ...      Credit Card              83
#
#   Total_Charges Total_Refunds Total_Extra_Data_Charges  \
# 0           593             0                        0
# ...

# %%
# checking to see if the changes have been effected in the data
data.dtypes
# Out:
# Customer_ID                          object
# Gender                               object
# Age                                   int32
# Married                              object
#  Dependents                           int32
# City                                 object
# Zip_Code                              int32
# Referrals                             int32
# Tenure                                int32
# Offer                                object
# Phone_Service                        object
# Avg_Monthly_Long_Distance_Charges     int32
# Multiple_Lines                       object
# Internet_Service                     object
# Internet_Type                        object
# Avg_Monthly_GB Download               int32
# Online_Security                      object
# Online_Backup                        object
# Device_Protection_Plan               object
# Premium Tech Support                 object
# Streaming_TV                         object
# ...

# %%
# exporting the cleaned dataset
data.to_csv(r'C:\Users\PC\Documents\Customer Churn Analysis\Cleaned_Data.csv')
